# %%
from certificados.models import Certificados, Estudiates, Solicitudes

# %%
e = Estudiates.objects.get(pk=1)

# %%
e
# Out:
# <Estudiates: Yurley>

# %%
e.certificado_set.all()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-4-357881216997> in <module>()
# ----> 1 e.certificado_set.all()
#
# AttributeError: 'Estudiates' object has no attribute 'certificado_set'

# %%
help(e)
# Out:
# Help on Estudiates in module certificados.models object:
#
# class Estudiates(django.db.models.base.Model)
#  |  Estudiates(id, nombre)
#  |
#  |  Method resolution order:
#  |      Estudiates
#  |      django.db.models.base.Model
#  |      builtins.object
#  |
#  |  Methods defined here:
#  |
#  |  __str__(self)
#  |      Return str(self).
#  |
#  |  id = <django.db.models.query_utils.DeferredAttribute object>
#  |  nombre = <django.db.models.query_utils.DeferredAttribute object>
#  |  ----------------------------------------------------------------------
#  |  Data descriptors defined here:
#  |
#  |  solicitudes_set
#  |      Accessor to the related objects manager on the reverse side of a
#  |      many-to-one relation.
#  |
#  |      In the example::
#  |
#  |          class Child(Model):
#  |              parent = ForeignKey(Parent, related_name='children')
#  |
#  |      ``Parent.children`` is a ``ReverseManyToOneDescriptor`` instance.
#  |
# ...

# %%
type(e.solicitudes_set)
# Out:
# django.db.models.fields.related_descriptors.create_reverse_many_to_one_manager.<locals>.RelatedManager

# %%
e.solicitudes_set.all()
# Out:
# <QuerySet [<Solicitudes: Yurley Estudiantil>, <Solicitudes: Yurley Notas>]>

# %%
help(e.solicitudes_set.all())
# Out:
# Help on QuerySet in module django.db.models.query object:
#
# class QuerySet(builtins.object)
#  |  Represent a lazy database lookup for a set of objects.
#  |
#  |  Methods defined here:
#  |
#  |  __and__(self, other)
#  |
#  |  __bool__(self)
#  |
#  |  __deepcopy__(self, memo)
#  |      Don't populate the QuerySet's cache.
#  |
#  |  __getitem__(self, k)
#  |      Retrieve an item or slice from the set of results.
#  |
#  |  __getstate__(self)
#  |
#  |  __init__(self, model=None, query=None, using=None, hints=None)
#  |      Initialize self.  See help(type(self)) for accurate signature.
#  |
#  |  __iter__(self)
#  |      The queryset iterator protocol uses three nested iterators in the
#  |      default case:
#  |          1. sql.compiler:execute_sql()
#  |             - Returns 100 rows at time (constants.GET_ITERATOR_CHUNK_SIZE)
#  |               using cursor.fetchmany(). This part is responsible for
# ...

# %%
e.solicitudes_set.all()

# %%
Certificados.objects.all().aggregate(Avg('valor'))
# Out:
# {'valor__avg': 13000.0}

# %%
from django.db.models import Count

# %%
q = Solicitudes.objects.annotate(Count('estudiante'))

# %%
help(q)
# Out:
# Help on QuerySet in module django.db.models.query object:
#
# class QuerySet(builtins.object)
#  |  Represent a lazy database lookup for a set of objects.
#  |
#  |  Methods defined here:
#  |
#  |  __and__(self, other)
#  |
#  |  __bool__(self)
#  |
#  |  __deepcopy__(self, memo)
#  |      Don't populate the QuerySet's cache.
#  |
#  |  __getitem__(self, k)
#  |      Retrieve an item or slice from the set of results.
#  |
#  |  __getstate__(self)
#  |
#  |  __init__(self, model=None, query=None, using=None, hints=None)
#  |      Initialize self.  See help(type(self)) for accurate signature.
#  |
#  |  __iter__(self)
#  |      The queryset iterator protocol uses three nested iterators in the
#  |      default case:
#  |          1. sql.compiler:execute_sql()
#  |             - Returns 100 rows at time (constants.GET_ITERATOR_CHUNK_SIZE)
#  |               using cursor.fetchmany(). This part is responsible for
# ...

# %%
q[3].estudiante__count
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-38-e2fe52bc6fe0> in <module>()
# ----> 1 q[3].estudiante__count
#
# ~\Desktop\Dev\dev9\DG_pulls20\venv\lib\site-packages\django\db\models\query.py in __getitem__(self, k)
#     305         qs.query.set_limits(k, k + 1)
#     306         qs._fetch_all()
# --> 307         return qs._result_cache[0]
#     308
#     309     def __and__(self, other):
#
# IndexError: list index out of range
